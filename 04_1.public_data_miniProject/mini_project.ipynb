# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib
from tabulate import tabulate
import csv

df_beef = pd.read_csv('Beef_Meat_Production.csv')
df_beef
# Out:
#          Country        Country2                                         Flag  \
# 0         Brazil          Brazil  https://www.countryflags.io/BR/shiny/64.png
# 1            USA             USA  https://www.countryflags.io/US/shiny/64.png
# 2          China           China  https://www.countryflags.io/CN/shiny/64.png
# 3      Argentina       Argentina  https://www.countryflags.io/AR/shiny/64.png
# 4      Australia       Australia  https://www.countryflags.io/AU/shiny/64.png
# 5         Mexico          Mexico  https://www.countryflags.io/MX/shiny/64.png
# 6         Russia          Russia  https://www.countryflags.io/RU/shiny/64.png
# 7         France          France  https://www.countryflags.io/FR/shiny/64.png
# 8        Germany         Germany  https://www.countryflags.io/DE/shiny/64.png
# 9   South Africa    South Africa  https://www.countryflags.io/ZA/shiny/64.png
# 10      Pakistan        Pakistan  https://www.countryflags.io/PK/shiny/64.png
# ...

# %%
df_beef.columns
# Out:
# Index(['Country', 'Country2', 'Flag', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967',
#        ...
#        'Unnamed: 108', 'Unnamed: 109', 'Unnamed: 110', 'Unnamed: 111',
#        'Unnamed: 112', 'Unnamed: 113', 'Unnamed: 114', 'Unnamed: 115',
#        'Unnamed: 116', 'Unnamed: 117'],
#       dtype='object', length=118)

# %%
Aus_beef = df_beef.iloc[4, 31:61]
Aus_beef = pd.to_numeric(Aus_beef, errors='coerce')

Aus_beef = Aus_beef.to_frame(name='beef_production')

Aus_beef.index.name = 'Year'

print(Aus_beef)
# Out:
#       beef_production
# Year
# 1989        1491478.0
# 1990        1676726.0
# 1991        1759569.0
# 1992        1790870.0
# 1993        1825813.0
# 1994        1824805.0
# 1995        1803417.0
# 1996        1744696.0
# 1997        1810300.0
# 1998        1955253.0
# 1999        2010530.0
# 2000        1987902.0
# 2001        2078900.0
# 2002        2089742.0
# 2003        1997563.0
# 2004        2112892.0
# 2005        2090272.0
# 2006        2188318.0
# 2007        2168946.0
# 2008        2138328.0
# 2009        2106385.0
# 2010        2128598.0
# 2011        2129021.0
# 2012        2152031.0
# 2013        2359064.0
# 2014        2595149.0
# 2015        2661640.0
# 2016        2315994.0
# 2017        2048517.0
# 2018        2162511.0

# %%
sns.lineplot(data=Aus_beef, x='Year', y='beef_production')
plt.xticks(rotation=60)
plt.title('호주 소고기 생산량')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
rock_weather = pd.read_excel('rockhampton_weather.xlsx')
rock_weather
# Out:
#     Year  mean_min_temp  mean_max_temp  mean_rainfall
# 0   1989           17.0           27.6         1111.8
# 1   1990           17.2           28.3         1398.4
# 2   1991           17.2           29.0          797.4
# 3   1992           16.8           28.6          490.4
# 4   1993           17.5           28.6          589.6
# 5   1994           16.2           28.9          519.2
# 6   1995           17.4           28.7          785.4
# 7   1996           17.0           28.8          728.8
# 8   1997           17.1           28.3          541.4
# 9   1998           17.9           28.9          782.8
# 10  1999           16.7           28.5          531.0
# 11  2000           16.5           27.9          900.4
# 12  2001           17.1           29.3          525.8
# 13  2002           17.2           29.7          360.0
# 14  2003           17.6           29.1          705.6
# 15  2004           17.1           29.8          413.0
# ...

# %%
weather = rock_weather.iloc[:,1:4]
weather
# Out:
#     mean_min_temp  mean_max_temp  mean_rainfall
# 0            17.0           27.6         1111.8
# 1            17.2           28.3         1398.4
# 2            17.2           29.0          797.4
# 3            16.8           28.6          490.4
# 4            17.5           28.6          589.6
# 5            16.2           28.9          519.2
# 6            17.4           28.7          785.4
# 7            17.0           28.8          728.8
# 8            17.1           28.3          541.4
# 9            17.9           28.9          782.8
# 10           16.7           28.5          531.0
# 11           16.5           27.9          900.4
# 12           17.1           29.3          525.8
# 13           17.2           29.7          360.0
# 14           17.6           29.1          705.6
# 15           17.1           29.8          413.0
# 16           17.7           29.5          634.0
# 17           17.3           28.8          587.6
# 18           17.2           28.4          681.2
# ...

# %%
corr=weather.corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='rocket')
plt.title('최고/최저기온과 강수량 히트맵')
plt.show()

# %%
sns.lineplot(data=rock_weather, x='Year', y='mean_min_temp', label='최저기온')
sns.lineplot(data=rock_weather, x='Year', y='mean_max_temp', label='최고기온')
plt.title('록햄프턴 최고/최저기온')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
sns.lineplot(data=rock_weather, x='Year', y='mean_rainfall')
plt.title('록햄프턴 강수량')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
df_test = pd.read_excel('for_test.xlsx')
test = df_test.iloc[:,1:]
# Out:
#     mean_min_temp  mean_max_temp  mean_rainfall     beef
# 0            17.0           27.6         1111.8  1491478
# 1            17.2           28.3         1398.4  1676726
# 2            17.2           29.0          797.4  1759569
# 3            16.8           28.6          490.4  1790870
# 4            17.5           28.6          589.6  1825813
# 5            16.2           28.9          519.2  1824805
# 6            17.4           28.7          785.4  1803417
# 7            17.0           28.8          728.8  1744696
# 8            17.1           28.3          541.4  1810300
# 9            17.9           28.9          782.8  1955253
# 10           16.7           28.5          531.0  2010530
# 11           16.5           27.9          900.4  1987902
# 12           17.1           29.3          525.8  2078900
# 13           17.2           29.7          360.0  2089742
# 14           17.6           29.1          705.6  1997563
# ...

# %%
corr=test.corr()
sns.heatmap(corr, annot=True, fmt='.2f', cmap='rocket')
plt.title('히트맵')
plt.show()
